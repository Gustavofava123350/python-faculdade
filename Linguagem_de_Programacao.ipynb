# %% [markdown]
# #u1_a1

# %%
print("Hello World !!")
# Out:
# Hello World !!

# %%
#2 variaveis

x = 10
nome = 'Gustavo'
nota = 8.90
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Gustavo
# 8.9
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type (fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("Digite seu nome:")
# Out:
# Digite seu nome:gustavo

# %%
print(f"Olá {nome}, bem vindo a aula de programaçao  ")
# Out:
# Olá gustavo, bem vindo a aula de programaçao

# %%
nota_1 = int(input("Digite a nota 1:"))
nota_2 = int(input("Digite a nota 2:"))
nota_3 = int(input("Digite a nota 3:"))
media = (nota_1 + nota_2 + nota_3)/3
print(f"A média é {media}")
# Out:
# Digite a nota 1:30
# Digite a nota 2:40
# Digite a nota 3:55
# A média é 41.666666666666664

# %% [markdown]
# u1_a2S

# %%
idade = 25
e_maior_de_idade = idade >= 18
print(e_maior_de_idade)
# Out:
# True

# %%
preco_ingresso = 25.00
ingressos_disponiveis = 100

print(f"Bem-vindo à Bilheteria! O preço do ingresso é R${preco_ingresso:.2f} e temos {ingressos_disponiveis} ingressos disponíveis.")
# Out:
# Bem-vindo à Bilheteria! O preço do ingresso é R$25.00 e temos 100 ingressos disponíveis.

# %%
idade = int(input('Digite sua idade: '))
if idade >= 18:
  print("Maior de idade")
else:
  print("Menor de idade")
# Out:
# Digite sua idade: 29
# Maior de idade

# %%
idade = int(input('Digite sua idade:'))
if idade <= 12:
  print('Recomendação de filmes para crianças')
elif idade <= 17:
  print('Recomendação de filmes para adolescentes')
else:
  print('Recomendação de filmes para adultos')

  # Iniciar a compra de ingressos para adultos
  quantidade_desejada = int(input('Digite a quantidade de ingressos que deseja comprar: '))

  if quantidade_desejada > 0 and quantidade_desejada <= ingressos_disponiveis:
    total_preco = quantidade_desejada * preco_ingresso
    ingressos_disponiveis -= quantidade_desejada
    print(f'Compra realizada com sucesso! O total é R${total_preco:.2f}.')
    print(f'Restam {ingressos_disponiveis} ingressos disponíveis.')
  elif quantidade_desejada > ingressos_disponiveis:
    print(f'Desculpe, só temos {ingressos_disponiveis} ingressos disponíveis.')
  else:
    print('Quantidade de ingressos inválida.')
# Out:
# Digite sua idade:29
# Recomendação de filmes para adultos
# Digite a quantidade de ingressos que deseja comprar: 12
# Compra realizada com sucesso! O total é R$300.00.
# Restam 88 ingressos disponíveis.
